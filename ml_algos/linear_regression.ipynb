# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X = np.random.rand(1,100) * 1000 # house area
y = 200 * X + 30000 + np.random.rand(1,100) * 10000 # house price

# %%
X = X.reshape(-1,1)
y = y.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model = LinearRegression()
model.fit(X_train,y_train)

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test,y_pred)

print(f"mse of the LR is {mse}")
# Out:
# mse of the LR is 5871839.288786883

# %%
plt.scatter(X_test, y_test, color = 'blue', label = "actual prices")
plt.plot(X_test,y_test,color='green',label="desired line")
plt.plot(X_test,y_pred,color='red',label="predicted line")
plt.legend()
plt.show()
